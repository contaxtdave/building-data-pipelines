# %%
import pandas as pd

root_dir = "/users/david/building-data-pipelines/chapter_7"

try:
    # Read the traffic crashes CSV file and store it in a dataframe
    df_crashes = pd.read_csv(f"{root_dir}/data/traffic_crashes.csv")
    
    # Read the traffic crash vehicle CSV file and store it in a dataframe")
    df__vehicles = pd.read_csv(f"{root_dir}/data/traffic_crash_vehicle.csv")

    # Read the traffic crash dPeole CSV file and store it in a dataframe
    df_people = pd.read_csv(f"{root_dir}/data/traffic_crash_people.csv")

except FileNotFoundError as e:
    # Handle exception if any of the files are missing
    print(f"Error: {e}")
except Exception as e:
    # Handle any other exceptions 
    print(f"Error: {e}")
